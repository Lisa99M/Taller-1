# %% [markdown]
# ## Séptimo punto
#
# Escriba un programa que pida 5 números reales y calcule las siguientes operaciones:
#
#     - El promedio
#     - La mediana
#     - El promedio multiplicativo (multilplica todos y luego calcula la raíz de la cantidad de operandos)
#     - Ordenar los números de forma ascendente
#     - Ordenar los números de forma descendente
#     - La potencia del mayor número elevado al menor número
#     - La raíz cúbica del menor número

# %%
a = float(input("Digite el primer número real: "))
b = float(input("Digite el segundo número real: "))
c = float(input("Digite el tercer número real: "))
d = float(input("Digite el cuarto número real: "))
e = float(input("Digite el quinto número real: "))

#Ordenamiento de los números ingresados

# Bloque de a mayor
if a>b and a>c and a>d and a>e:
    mayor = a
    if b>c and b>d and b>e:
        medio3 = b
        if c>d and c>e:
            medio2 = e
            if d>e:
                medio1 = d
                menor = e
            else:
                medio1=e
                menor=d
        elif d>c and d>e:
            medio2=d
            if c>e:
                medio1=c
                menor=e
            else: 
                medio1=e
                menor=c
        elif e>c and e>d:
            medio2=e
            if c>d:
                medio1=c
                menor=d
            else:
                medio1=d
                menor=c
    elif c>b and c>d and c>e:
        medio3 = c
        if b>d and b>e:
            medio2=b
            if  d>e:
                medio1=d
                menor=e
            else:
                medio1=e
                menor=d
        elif d>b and d>e:
            medio2=d
            if b>e:
                medio1=b
                menor=e
            else:
                medio1=e
                menor=b
        elif e>b and e>d:
            medio2=e
            if b>d:
                medio1=b
                menor=d
            else:
                medio1=d
                menor=b
    elif d>b and d>c and d>e:
        medio3=d
        if b>c and b>e:
            medio2=b
            if c>e:
                medio1=c
                menor=e
            else: 
                medio1=e
                menor=c
        elif c>b and c>e:
            medio2=c
            if b>e:
                medio1=b
                menor=e
            else:
                medio1=e
                menor=b
        if e>b and e>c:
            medio2=e
            if b>c:
                medio1=b
                menor=c
            else:
                medio1=c
                menor=b
    elif e>b and e>c and e>d:
        medio3=e
        if b>c and b>d:
            medio2=b
            if c>d:
                medio1=c
                menor=d
            else: 
                medio1=d
                menor=c
        elif c>b and c>d:
            medio2=c
            if b>d:
                medio1=b
                menor=d
            else:
                medio1=d
                menor=b
        elif d>b and d>c:
            medio2=d
            if b>c:
                medio1=b
                menor=c
            else:
                medio1=c
                menor=b
# Bloque de b mayor
elif b>a and b>c and b>d and b>e:
    mayor = b
    if a>c and a>d and a>e:
        medio3 = a
        if c>d and c>e:
            medio2 = c
            if d>e:
                medio1 = d
                menor = e
            else:
                medio1=e
                menor=d
        elif d>c and d>e:
            medio2=d
            if c>e:
                medio1=c
                menor=e
            else: 
                medio1=e
                menor=c
        elif e>c and e>d:
            medio2=e
            if c>d:
                medio1=c
                menor=d
            else:
                medio1=d
                menor=c
    elif c>a and c>d and c>e:
        medio3 = c
        if a>d and a>e:
            medio2=a
            if  d>e:
                medio1=d
                menor=e
            else:
                medio1=e
                menor=d
        elif d>a and d>e:
            medio2=d
            if a>e:
                medio1=a
                menor=e
            else:
                medio1=e
                menor=a
        elif e>a and e>d:
            medio2=e
            if a>d:
                medio1=a
                menor=d
            else:
                medio1=d
                menor=a
    elif d>a and d>c and d>e:
        medio3=d
        if a>c and a>e:
            medio2=a
            if c>e:
                medio1=c
                menor=e
            else: 
                medio1=e
                menor=c
        elif c>a and c>e:
            medio2=c
            if a>e:
                medio1=a
                menor=e
            else:
                medio1=e
                menor=a
        if e>a and e>c:
            medio2=e
            if a>c:
                medio1=a
                menor=c
            else:
                medio1=c
                menor=a
    elif e>a and e>c and e>d:
        medio3=e
        if a>c and a>d:
            medio2=b
            if c>d:
                medio1=c
                menor=d
            else: 
                medio1=d
                menor=c
        elif c>a and c>d:
            medio2=c
            if a>d:
                medio1=a
                menor=d
            else:
                medio1=d
                menor=a
        elif d>a and d>c:
            medio2=d
            if a>c:
                medio1=a
                menor=c
            else:
                medio1=c
                menor=a
# Bloque de c mayor
elif c>a and c>b and c>d and c>e:
    mayor = c
    if a>b and a>d and a>e:
        medio3 = a
        if b>d and b>e:
            medio2 = b
            if d>e:
                medio1 = d
                menor = e
            else:
                medio1=e
                menor=d
        elif d>b and d>e:
            medio2=d
            if b>e:
                medio1=b
                menor=e
            else: 
                medio1=e
                menor=b
        elif e>b and e>d:
            medio2=e
            if b>d:
                medio1=b
                menor=d
            else:
                medio1=d
                menor=b
    elif b>a and b>d and b>e:
        medio3 = b
        if a>d and a>e:
            medio2=a
            if  d>e:
                medio1=d
                menor=e
            else:
                medio1=e
                menor=d
        elif d>a and d>e:
            medio2=d
            if a>e:
                medio1=a
                menor=e
            else:
                medio1=e
                menor=a
        elif e>a and e>d:
            medio2=e
            if a>d:
                medio1=a
                menor=d
            else:
                medio1=d
                menor=a
    elif d>a and d>b and d>e:
        medio3=d
        if a>b and a>e:
            medio2=a
            if b>e:
                medio1=b
                menor=e
            else: 
                medio1=e
                menor=b
        elif b>a and b>e:
            medio2=b
            if a>e:
                medio1=a
                menor=e
            else:
                medio1=e
                menor=a
        if e>a and e>b:
            medio2=e
            if a>b:
                medio1=a
                menor=b
            else:
                medio1=b
                menor=a
    elif e>a and e>b and e>d:
        medio3=e
        if a>b and a>d:
            medio2=a
            if b>d:
                medio1=b
                menor=d
            else: 
                medio1=d
                menor=b
        elif b>a and b>d:
            medio2=b
            if a>d:
                medio1=a
                menor=d
            else:
                medio1=d
                menor=a
        elif d>a and d>b:
            medio2=d
            if a>b:
                medio1=a
                menor=b
            else:
                medio1=b
                menor=a
# Bloque de d mayor
elif d>a and d>b and d>c and d>e:
    mayor = d
    if a>b and a>c and a>e:
        medio3 = a
        if b>c and b>e:
            medio2 = b
            if c>e:
                medio1 = c
                menor = e
            else:
                medio1=e
                menor=c
        elif c>b and c>e:
            medio2=c
            if b>e:
                medio1=b
                menor=e
            else: 
                medio1=e
                menor=b
        elif e>b and e>c:
            medio2=e
            if b>c:
                medio1=b
                menor=c
            else:
                medio1=c
                menor=b
    elif b>a and b>c and b>e:
        medio3 = b
        if a>c and a>e:
            medio2=a
            if  c>e:
                medio1=c
                menor=e
            else:
                medio1=e
                menor=c
        elif c>a and c>e:
            medio2=c
            if a>e:
                medio1=a
                menor=e
            else:
                medio1=e
                menor=a
        elif e>a and e>c:
            medio2=e
            if a>c:
                medio1=a
                menor=c
            else:
                medio1=d
                menor=c
    elif c>a and c>b and c>e:
        medio3=c
        if a>b and a>e:
            medio2=a
            if b>e:
                medio1=b
                menor=e
            else: 
                medio1=e
                menor=b
        elif b>a and b>e:
            medio2=b
            if a>e:
                medio1=a
                menor=e
            else:
                medio1=e
                menor=a
        if e>a and e>b:
            medio2=e
            if a>b:
                medio1=a
                menor=b
            else:
                medio1=b
                menor=a
    elif e>a and e>b and e>c:
        medio3=e
        if a>b and a>c:
            medio2=a
            if b>c:
                medio1=b
                menor=c
            else: 
                medio1=d
                menor=c
        elif b>a and b>c:
            medio2=b
            if a>c:
                medio1=a
                menor=c
            else:
                medio1=c
                menor=a
        elif c>a and c>b:
            medio2=c
            if a>b:
                medio1=a
                menor=b
            else:
                medio1=b
                menor=a
# Bloque de e mayor
elif e>a and e>b and e>c and e>d:
    mayor = e
    if a>b and a>c and a>d:
        medio3 = a
        if b>c and b>d:
            medio2 = b
            if c>d:
                medio1 = c
                menor = d
            else:
                medio1=d
                menor=c
        elif c>b and c>d:
            medio2=c
            if b>d:
                medio1=b
                menor=d
            else: 
                medio1=d
                menor=b
        elif d>b and d>c:
            medio2=d
            if b>c:
                medio1=b
                menor=c
            else:
                medio1=c
                menor=b
    elif b>a and b>c and b>d:
        medio3 = b
        if a>c and a>d:
            medio2=a
            if  c>d:
                medio1=c
                menor=d
            else:
                medio1=d
                menor=c
        elif c>a and c>d:
            medio2=c
            if a>d:
                medio1=a
                menor=d
            else:
                medio1=d
                menor=a
        elif d>a and d>c:
            medio2=d
            if a>c:
                medio1=a
                menor=c
            else:
                medio1=d
                menor=c
    elif c>a and c>b and c>d:
        medio3=c
        if a>b and a>d:
            medio2=a
            if b>d:
                medio1=b
                menor=d
            else: 
                medio1=d
                menor=b
        elif b>a and b>d:
            medio2=b
            if a>d:
                medio1=a
                menor=d
            else:
                medio1=d
                menor=a
        if d>a and d>b:
            medio2=d
            if a>b:
                medio1=a
                menor=b
            else:
                medio1=b
                menor=a
    elif d>a and d>b and d>c:
        medio3=d
        if a>b and a>c:
            medio2=a
            if b>c:
                medio1=b
                menor=c
            else: 
                medio1=d
                menor=c
        elif b>a and b>c:
            medio2=b
            if a>c:
                medio1=a
                menor=c
            else:
                medio1=c
                menor=a
        elif c>a and c>b:
            medio2=c
            if a>b:
                medio1=a
                menor=b
            else:
                medio1=b
                menor=a

promedio = (a + b + c + d + e) / 5
print("El promedio de los números ingresados es: " + str(promedio)+"\n")
   
print("La mediana de los números ingresados es: " + str(medio2)+"\n")
    
pmult = (a*b*c*d*e)**(1/5)
print("El promedio multiplicativo de los números ingresados es: " + str(pmult)+"\n")

print("Los números ingresados ordenados de forma ascendente: " + str(menor)+" , "+str(medio1)+" , "+str(medio2)+" , "+str(medio3)+" , "+str(mayor)+"\n")
 
print("Los números ingresados ordenados de forma ascendente: " + str(mayor)+" , "+str(medio3)+" , "+str(medio2)+" , "+str(medio1)+" , "+str(menor)+"\n")
 
pot = mayor**menor
print("La potencia del número mayor elevado al número menor es: "+str(pot)+"\n")

raiz = menor ** (1/3)
print("La raíz cúbica del número menor es: "+str(raiz))
